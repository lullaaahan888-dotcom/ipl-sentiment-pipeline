# %% [markdown]
# # IPL Sentiment Pipeline Selector Lab
# ## Beginner-friendly vectorizer × classifier experiment notebook
#
# This notebook helps you **choose good vectorizers and classifiers** for the IPL sentiment challenge.
#
# You will:
#
# 1. Load the IPL sentiment dataset from GitHub.
# 2. Understand the columns: `statement`, `subject_keyword`, and `sentiment`.
# 3. Add vectorizer recipes using beginner-friendly helper functions.
# 4. Add classifier recipes using beginner-friendly helper functions.
# 5. Automatically train all vectorizer × classifier combinations.
# 6. Compare pipelines using accuracy, Macro F1, speed, model size, and simplicity.
# 7. Shortlist models for the 300-row round.
# 8. Select your final **4 vectorizers + 4 classifiers**.
# 9. Generate a JSON submission that you can copy-paste into the Django webapp.
#
# Dataset source used by default:
#
# `https://raw.githubusercontent.com/HimanshuKhale/ipl_sentiment/main/ipl_sentiment_small_dataset.csv`
#
# Important: Your goal is **not** to use the heaviest model. Your goal is to choose a useful, explainable, diverse, and efficient set of pipeline components.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Submission philosophy
#
# In this sprint, you are not only competing for accuracy.
#
# A good submission should show:
#
# - **Variety**: different vectorizer families and classifier families.
# - **Reasoning**: why you chose each vectorizer and classifier.
# - **Suitability**: simple models should be rewarded when they perform well.
# - **Efficiency**: smaller/faster models are valuable.
# - **Generalization**: models should work beyond one small dataset.
#
# Bad strategy:
#
# > Submit 4 versions of the same TF-IDF and 4 heavy classifiers.
#
# Good strategy:
#
# > Compare CountVectorizer, word TF-IDF, character TF-IDF, and HashingVectorizer with Naive Bayes, Logistic Regression, LinearSVC, and SGDClassifier.

# %%
# ============================================================
# STEP 0: Install/import libraries
# ============================================================

# !pip install pandas numpy scikit-learn matplotlib joblib

import json
import time
import os
import warnings
from pathlib import Path
from copy import deepcopy

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import joblib

from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score

from sklearn.metrics import (
    accuracy_score,
    f1_score,
    precision_score,
    recall_score,
    confusion_matrix,
    classification_report,
)

from sklearn.feature_extraction.text import (
    CountVectorizer,
    TfidfVectorizer,
    HashingVectorizer
)

from sklearn.naive_bayes import (
    MultinomialNB,
    ComplementNB,
    BernoulliNB
)

from sklearn.linear_model import (
    LogisticRegression,
    SGDClassifier,
    RidgeClassifier,
    PassiveAggressiveClassifier
)

from sklearn.svm import LinearSVC
from sklearn.ensemble import RandomForestClassifier

from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import FunctionTransformer, Normalizer

warnings.filterwarnings("ignore")

RANDOM_STATE = 42

print("Libraries loaded successfully.")
# Out:
# Libraries loaded successfully.

# %%
# ============================================================
# STEP 1: Load the 80-row dataset from GitHub
# ============================================================

DATA_URL_80R = "/content/ipl_sentiment_80r.csv"

LOCAL_DATA_PATH_80R = "/content/ipl_sentiment_80r.csv"

def load_dataset_from_github_or_local(url, local_path):
    try:
        df = pd.read_csv(url)
        print("Loaded dataset from GitHub:", url)
        return df
    except Exception as github_error:
        print("Could not load from GitHub. Trying local file...")
        print("GitHub error:", github_error)
        if Path(local_path).exists():
            df = pd.read_csv(local_path)
            print("Loaded local dataset:", local_path)
            return df
        raise FileNotFoundError(
            "Dataset could not be loaded from GitHub or local file. "
            "Please download the CSV and put it next to this notebook."
        )

df_80 = load_dataset_from_github_or_local(DATA_URL_80R, LOCAL_DATA_PATH_80R)

print("Shape:", df_80.shape)
display(df_80.head())
print("Columns:", list(df_80.columns))
# Out:
# Loaded dataset from GitHub: /content/ipl_sentiment_80r.csv
# Shape: (80, 4)
#    post_id                                          statement subject_keyword  \
# 0        1  RCB finally played like champions today, the b...             RCB
# 1        2  RCB fans deserve better than another middle or...             RCB
# 2        3  RCB's batting was decent but the fielding stil...             RCB
# 3        4  Virat's energy makes RCB matches feel electric...             RCB
# 4        5  RCB again lost control in the death overs, sam...             RCB
#
#   sentiment
# 0  positive
# 1  negative
# 2   neutral
# 3  positive
# 4  negative
# Columns: ['post_id', 'statement', 'subject_keyword', 'sentiment']

# %%
# ============================================================
# STEP 2: Clean and standardize the dataset
# ============================================================

# Required columns:
# statement = tweet/post text
# subject_keyword = IPL team or subject
# sentiment = positive/negative/neutral

required_columns = ["statement", "subject_keyword", "sentiment"]

missing = [col for col in required_columns if col not in df_80.columns]
if missing:
    raise ValueError(f"Missing required columns: {missing}. Your dataset must have {required_columns}")

df_80 = df_80.dropna(subset=required_columns).copy()
df_80["statement"] = df_80["statement"].astype(str)
df_80["subject_keyword"] = df_80["subject_keyword"].astype(str)
df_80["sentiment"] = df_80["sentiment"].astype(str).str.lower().str.strip()

# Entity-aware model text:
# This helps the model learn sentiment toward the keyword, not just general sentiment.
df_80["model_text"] = df_80["subject_keyword"] + " [SEP] " + df_80["statement"]

print("Cleaned shape:", df_80.shape)
print("\nSentiment distribution:")
display(df_80["sentiment"].value_counts())

print("\nTeam/keyword distribution:")
display(df_80["subject_keyword"].value_counts())

display(df_80[["model_text", "sentiment"]].head())
# Out:
# Cleaned shape: (80, 5)
#
# Sentiment distribution:
# sentiment
# positive    28
# negative    26
# neutral     26
# Name: count, dtype: int64
# Team/keyword distribution:
# subject_keyword
# RCB     8
# MI      8
# CSK     8
# KKR     8
# SRH     8
# RR      8
# DC      8
# PBKS    8
# GT      8
# LSG     8
# Name: count, dtype: int64
#                                           model_text sentiment
# 0  RCB [SEP] RCB finally played like champions to...  positive
# 1  RCB [SEP] RCB fans deserve better than another...  negative
# 2  RCB [SEP] RCB's batting was decent but the fie...   neutral
# 3  RCB [SEP] Virat's energy makes RCB matches fee...  positive
# 4  RCB [SEP] RCB again lost control in the death ...  negative

# %%
# ============================================================
# STEP 3: Create train/test split for the 80R experiment
# ============================================================

X = df_80["model_text"]
y = df_80["sentiment"]

X_train_80, X_test_80, y_train_80, y_test_80 = train_test_split(
    X,
    y,
    test_size=0.25,
    random_state=RANDOM_STATE,
    stratify=y
)

print("Training rows:", len(X_train_80))
print("Testing rows:", len(X_test_80))
print("\nTrain label distribution:")
display(y_train_80.value_counts())
print("\nTest label distribution:")
display(y_test_80.value_counts())
# Out:
# Training rows: 60
# Testing rows: 20
#
# Train label distribution:
# sentiment
# positive    21
# neutral     20
# negative    19
# Name: count, dtype: int64
# Test label distribution:
# sentiment
# positive    7
# negative    7
# neutral     6
# Name: count, dtype: int64

# %% [markdown]
# # STEP 4: Beginner-friendly recipe system
#
# You do **not** need to write complex registration code.
#
# You only need to call:
#
# ```python
# add_vectorizer(...)
# add_classifier(...)
# ```
#
# Each vectorizer/classifier becomes a **recipe**.
# The notebook will later convert recipes into real sklearn objects.
#
# A recipe has:
#
# - `id`: short unique name
# - `name`: readable name
# - `family`: category, such as `count`, `tfidf_word`, `tfidf_char`, `hashing`
# - `type`: sklearn class name
# - `params`: settings
# - `notes`: why you chose it
# - `complexity`: `low`, `medium`, or `high`

# %%
# ============================================================
# STEP 4A: Helper functions for adding recipes
# ============================================================

vectorizer_recipes = []
classifier_recipes = []

def add_vectorizer(id, name, family, type, params=None, notes="", complexity="low"):
    """
    Add a vectorizer recipe.

    Example:
    add_vectorizer(
        id="tfidf_word_1_2",
        name="TF-IDF Word 1-2 grams",
        family="tfidf_word",
        type="TfidfVectorizer",
        params={"ngram_range": (1, 2), "max_features": 3000},
        notes="Good baseline for short text.",
        complexity="low"
    )
    """
    if params is None:
        params = {}
    vectorizer_recipes.append({
        "id": id,
        "name": name,
        "family": family,
        "type": type,
        "params": params,
        "notes": notes,
        "complexity": complexity,
    })

def add_classifier(id, name, family, type, params=None, notes="", complexity="low"):
    """
    Add a classifier recipe.

    Example:
    add_classifier(
        id="logreg_balanced",
        name="Logistic Regression Balanced",
        family="linear",
        type="LogisticRegression",
        params={"max_iter": 1000, "class_weight": "balanced"},
        notes="Strong simple classifier for sparse text.",
        complexity="low"
    )
    """
    if params is None:
        params = {}
    classifier_recipes.append({
        "id": id,
        "name": name,
        "family": family,
        "type": type,
        "params": params,
        "notes": notes,
        "complexity": complexity,
    })

print("Helper functions are ready.")
# Out:
# Helper functions are ready.

# %%
# ============================================================
# STEP 4B: 10 vectorizers
# ============================================================

add_vectorizer(
    id="count_word",
    name="CountVectorizer Word",
    family="count",
    type="CountVectorizer",
    params={"lowercase": True, "max_features": 3000},
    notes="Simple word frequency baseline.",
    complexity="low"
)

add_vectorizer(
    id="count_binary",
    name="Binary CountVectorizer",
    family="count_binary",
    type="CountVectorizer",
    params={"lowercase": True, "binary": True, "max_features": 3000},
    notes="Tests word presence instead of frequency.",
    complexity="low"
)

add_vectorizer(
    id="count_bigram",
    name="CountVectorizer 1-2 grams",
    family="count_ngram",
    type="CountVectorizer",
    params={"lowercase": True, "ngram_range": (1, 2), "max_features": 4000},
    notes="Captures simple word frequencies and short phrases.",
    complexity="low"
)

add_vectorizer(
    id="tfidf_word",
    name="TF-IDF Word",
    family="tfidf",
    type="TfidfVectorizer",
    params={"lowercase": True, "max_features": 4000},
    notes="Weights important words more strongly.",
    complexity="low"
)

add_vectorizer(
    id="tfidf_bigram",
    name="TF-IDF 1-2 grams",
    family="tfidf_ngram",
    type="TfidfVectorizer",
    params={"lowercase": True, "ngram_range": (1, 2), "max_features": 4000},
    notes="Weights important words and short phrases.",
    complexity="low"
)

add_vectorizer(
    id="tfidf_char",
    name="Character TF-IDF",
    family="char_tfidf",
    type="TfidfVectorizer",
    params={"analyzer": "char", "ngram_range": (3, 5), "max_features": 5000},
    notes="Handles slang, typos, and repeated letters.",
    complexity="medium"
)

add_vectorizer(
    id="tfidf_char_wb",
    name="Character WB TF-IDF",
    family="char_wb_tfidf",
    type="TfidfVectorizer",
    params={"analyzer": "char_wb", "ngram_range": (3, 5), "max_features": 5000},
    notes="Character n-grams within word boundaries for noisy text.",
    complexity="medium"
)

add_vectorizer(
    id="hashing_word",
    name="HashingVectorizer Word",
    family="hashing",
    type="HashingVectorizer",
    params={"alternate_sign": False, "n_features": 2048, "lowercase": True},
    notes="Memory-efficient word hashing without storing vocabulary.",
    complexity="medium"
)

add_vectorizer(
    id="hashing_char",
    name="HashingVectorizer Character",
    family="char_hashing",
    type="HashingVectorizer",
    params={"alternate_sign": False, "n_features": 4096, "analyzer": "char", "ngram_range": (3, 5)},
    notes="Memory-efficient character-level hashing.",
    complexity="medium"
)

add_vectorizer(
    id="tfidf_svd",
    name="TF-IDF + SVD",
    family="dimensionality_reduction",
    type="TfidfSVD",
    params={},
    notes="Compresses TF-IDF into lower-dimensional features.",
    complexity="high"
)

print(f"Total vectorizers added: {len(vectorizer_recipes)}")
pd.DataFrame(vectorizer_recipes)
# Out:
# Total vectorizers added: 10
#               id                         name                    family  \
# 0     count_word         CountVectorizer Word                     count
# 1   count_binary       Binary CountVectorizer              count_binary
# 2   count_bigram    CountVectorizer 1-2 grams               count_ngram
# 3     tfidf_word                  TF-IDF Word                     tfidf
# 4   tfidf_bigram             TF-IDF 1-2 grams               tfidf_ngram
# 5     tfidf_char             Character TF-IDF                char_tfidf
# 6  tfidf_char_wb          Character WB TF-IDF             char_wb_tfidf
# 7   hashing_word       HashingVectorizer Word                   hashing
# 8   hashing_char  HashingVectorizer Character              char_hashing
# 9      tfidf_svd                 TF-IDF + SVD  dimensionality_reduction
#
#                 type                                             params  \
# 0    CountVectorizer          {'lowercase': True, 'max_features': 3000}
# 1    CountVectorizer  {'lowercase': True, 'binary': True, 'max_featu...
# 2    CountVectorizer  {'lowercase': True, 'ngram_range': (1, 2), 'ma...
# 3    TfidfVectorizer          {'lowercase': True, 'max_features': 4000}
# 4    TfidfVectorizer  {'lowercase': True, 'ngram_range': (1, 2), 'ma...
# 5    TfidfVectorizer  {'analyzer': 'char', 'ngram_range': (3, 5), 'm...
# 6    TfidfVectorizer  {'analyzer': 'char_wb', 'ngram_range': (3, 5),...
# 7  HashingVectorizer  {'alternate_sign': False, 'n_features': 2048, ...
# 8  HashingVectorizer  {'alternate_sign': False, 'n_features': 4096, ...
# 9           TfidfSVD                                                 {}
#
#                                                notes complexity
# 0                    Simple word frequency baseline.        low
# 1          Tests word presence instead of frequency.        low
# 2  Captures simple word frequencies and short phr...        low
# 3             Weights important words more strongly.        low
# 4         Weights important words and short phrases.        low
# 5        Handles slang, typos, and repeated letters.     medium
# 6  Character n-grams within word boundaries for n...     medium
# 7  Memory-efficient word hashing without storing ...     medium
# 8          Memory-efficient character-level hashing.     medium
# 9  Compresses TF-IDF into lower-dimensional featu...       high

# %%
# ============================================================
# STEP 4C: 10 classifiers
# ============================================================

add_classifier(
    id="multinomial_nb",
    name="Multinomial Naive Bayes",
    family="naive_bayes",
    type="MultinomialNB",
    params={},
    notes="Very fast probabilistic baseline for text counts.",
    complexity="low"
)

add_classifier(
    id="complement_nb",
    name="Complement Naive Bayes",
    family="naive_bayes",
    type="ComplementNB",
    params={},
    notes="Naive Bayes variant useful for imbalanced text data.",
    complexity="low"
)

add_classifier(
    id="bernoulli_nb",
    name="Bernoulli Naive Bayes",
    family="naive_bayes",
    type="BernoulliNB",
    params={},
    notes="Uses feature presence/absence logic.",
    complexity="low"
)

add_classifier(
    id="logreg_balanced",
    name="Logistic Regression Balanced",
    family="linear",
    type="LogisticRegression",
    params={"max_iter": 1000, "class_weight": "balanced", "random_state": RANDOM_STATE},
    notes="Simple explainable linear classifier.",
    complexity="low"
)

add_classifier(
    id="ridge_classifier",
    name="Ridge Classifier",
    family="linear",
    type="RidgeClassifier",
    params={},
    notes="Regularized linear classifier.",
    complexity="low"
)

add_classifier(
    id="linear_svc",
    name="LinearSVC",
    family="margin_based",
    type="LinearSVC",
    params={"random_state": RANDOM_STATE},
    notes="Strong margin-based classifier for sparse text.",
    complexity="medium"
)

add_classifier(
    id="sgd_log",
    name="SGDClassifier Logistic Loss",
    family="sgd",
    type="SGDClassifier",
    params={"loss": "log_loss", "max_iter": 1000, "random_state": RANDOM_STATE},
    notes="Scalable logistic classifier.",
    complexity="medium"
)

add_classifier(
    id="sgd_hinge",
    name="SGDClassifier Hinge Loss",
    family="sgd",
    type="SGDClassifier",
    params={"loss": "hinge", "max_iter": 1000, "random_state": RANDOM_STATE},
    notes="Scalable SVM-like classifier.",
    complexity="medium"
)

add_classifier(
    id="passive_aggressive",
    name="Passive Aggressive Classifier",
    family="online_margin",
    type="PassiveAggressiveClassifier",
    params={"max_iter": 1000, "random_state": RANDOM_STATE},
    notes="Fast online margin-based classifier.",
    complexity="medium"
)

add_classifier(
    id="random_forest_small",
    name="Small Random Forest",
    family="tree_based",
    type="RandomForestClassifier",
    params={"n_estimators": 50, "max_depth": 10, "random_state": RANDOM_STATE},
    notes="One nonlinear tree-based model for comparison.",
    complexity="high"
)

print(f"Total classifiers added: {len(classifier_recipes)}")
pd.DataFrame(classifier_recipes)
# Out:
# Total classifiers added: 10
#                     id                           name         family  \
# 0       multinomial_nb        Multinomial Naive Bayes    naive_bayes
# 1        complement_nb         Complement Naive Bayes    naive_bayes
# 2         bernoulli_nb          Bernoulli Naive Bayes    naive_bayes
# 3      logreg_balanced   Logistic Regression Balanced         linear
# 4     ridge_classifier               Ridge Classifier         linear
# 5           linear_svc                      LinearSVC   margin_based
# 6              sgd_log    SGDClassifier Logistic Loss            sgd
# 7            sgd_hinge       SGDClassifier Hinge Loss            sgd
# 8   passive_aggressive  Passive Aggressive Classifier  online_margin
# 9  random_forest_small            Small Random Forest     tree_based
#
#                           type  \
# 0                MultinomialNB
# 1                 ComplementNB
# 2                  BernoulliNB
# 3           LogisticRegression
# 4              RidgeClassifier
# 5                    LinearSVC
# 6                SGDClassifier
# 7                SGDClassifier
# 8  PassiveAggressiveClassifier
# 9       RandomForestClassifier
#
#                                               params  \
# 0                                                 {}
# 1                                                 {}
# 2                                                 {}
# 3  {'max_iter': 1000, 'class_weight': 'balanced',...
# 4                                                 {}
# 5                               {'random_state': 42}
# 6  {'loss': 'log_loss', 'max_iter': 1000, 'random...
# 7  {'loss': 'hinge', 'max_iter': 1000, 'random_st...
# 8             {'max_iter': 1000, 'random_state': 42}
# 9  {'n_estimators': 50, 'max_depth': 10, 'random_...
#
#                                                notes complexity
# 0  Very fast probabilistic baseline for text counts.        low
# 1  Naive Bayes variant useful for imbalanced text...        low
# 2               Uses feature presence/absence logic.        low
# 3              Simple explainable linear classifier.        low
# 4                     Regularized linear classifier.        low
# 5    Strong margin-based classifier for sparse text.     medium
# 6                      Scalable logistic classifier.     medium
# 7                      Scalable SVM-like classifier.     medium
# 8               Fast online margin-based classifier.     medium
# 9     One nonlinear tree-based model for comparison.       high

# %%
# ============================================================
# STEP 5: Validate diversity rules
# ============================================================

def validate_recipe_diversity(vectorizers, classifiers):
    messages = []

    v_families = sorted(set(v["family"] for v in vectorizers))
    c_families = sorted(set(c["family"] for c in classifiers))
    heavy_classifiers = [c for c in classifiers if c.get("complexity") == "high"]

    messages.append(f"Vectorizer count: {len(vectorizers)}")
    messages.append(f"Classifier count: {len(classifiers)}")
    messages.append(f"Vectorizer families: {v_families}")
    messages.append(f"Classifier families: {c_families}")
    messages.append(f"Heavy classifiers: {[c['id'] for c in heavy_classifiers]}")

    warnings = []
    if len(vectorizers) < 4:
        warnings.append("Add at least 4 vectorizers before final submission.")
    if len(classifiers) < 4:
        warnings.append("Add at least 4 classifiers before final submission.")
    if len(v_families) < 3:
        warnings.append("Use at least 3 different vectorizer families.")
    if len(c_families) < 3:
        warnings.append("Use at least 3 different classifier families.")
    if len(heavy_classifiers) > 1:
        warnings.append("Use maximum 1 heavy classifier.")

    return messages, warnings

messages, warnings_list = validate_recipe_diversity(vectorizer_recipes, classifier_recipes)

print("\n".join(messages))
if warnings_list:
    print("\nWarnings:")
    for w in warnings_list:
        print("-", w)
else:
    print("\nDiversity check passed.")
# Out:
# Vectorizer count: 10
# Classifier count: 10
# Vectorizer families: ['char_hashing', 'char_tfidf', 'char_wb_tfidf', 'count', 'count_binary', 'count_ngram', 'dimensionality_reduction', 'hashing', 'tfidf', 'tfidf_ngram']
# Classifier families: ['linear', 'margin_based', 'naive_bayes', 'online_margin', 'sgd', 'tree_based']
# Heavy classifiers: ['random_forest_small']
#
# Diversity check passed.

# %%
# ============================================================
# STEP 6: Build actual sklearn objects from recipes
# ============================================================

VECTORIZER_CLASSES = {
    "CountVectorizer": CountVectorizer,
    "TfidfVectorizer": TfidfVectorizer,
    "HashingVectorizer": HashingVectorizer,
}

CLASSIFIER_CLASSES = {
    "MultinomialNB": MultinomialNB,
    "ComplementNB": ComplementNB,
    "BernoulliNB": BernoulliNB,
    "LogisticRegression": LogisticRegression,
    "RidgeClassifier": RidgeClassifier,
    "LinearSVC": LinearSVC,
    "SGDClassifier": SGDClassifier,
    "PassiveAggressiveClassifier": PassiveAggressiveClassifier,
    "RandomForestClassifier": RandomForestClassifier,
}

def clean_params(params):
    params = deepcopy(params)
    if "ngram_range" in params and isinstance(params["ngram_range"], list):
        params["ngram_range"] = tuple(params["ngram_range"])
    return params

def build_vectorizer(recipe):
    if recipe["type"] == "TfidfSVD":
        return Pipeline([
            ("tfidf", TfidfVectorizer(
                lowercase=True,
                ngram_range=(1, 2),
                max_features=5000
            )),
            ("svd", TruncatedSVD(n_components=20, random_state=RANDOM_STATE)),
            ("abs", FunctionTransformer(lambda X: np.abs(X))),
            ("norm", Normalizer())
        ])

    cls = VECTORIZER_CLASSES[recipe["type"]]
    return cls(**clean_params(recipe.get("params", {})))

def build_classifier(recipe):
    cls = CLASSIFIER_CLASSES[recipe["type"]]
    return cls(**clean_params(recipe.get("params", {})))

def make_pipeline(vectorizer_recipe, classifier_recipe):
    return Pipeline([
        ("vectorizer", build_vectorizer(vectorizer_recipe)),
        ("classifier", build_classifier(classifier_recipe)),
    ])

print("Factory functions are ready.")
# Out:
# Factory functions are ready.

# %%
# ============================================================
# STEP 7: Train every vectorizer × classifier combination on 80R
# ============================================================

def estimate_model_size_kb(model, temp_path="temp_pipeline_model.joblib"):
    try:
        joblib.dump(model, temp_path)
        size_kb = os.path.getsize(temp_path) / 1024
        os.remove(temp_path)
        return size_kb
    except Exception:
        return np.nan

def complexity_penalty(v_recipe, c_recipe):
    # Higher complexity gets a small penalty in suitability score.
    levels = {"low": 0, "medium": 1, "high": 2}
    return levels.get(v_recipe.get("complexity", "low"), 0) + levels.get(c_recipe.get("complexity", "low"), 0)

def run_single_pipeline(v_recipe, c_recipe, X_train, X_test, y_train, y_test):
    result = {
        "vectorizer_id": v_recipe["id"],
        "vectorizer_name": v_recipe["name"],
        "vectorizer_family": v_recipe["family"],
        "vectorizer_complexity": v_recipe.get("complexity", "low"),
        "classifier_id": c_recipe["id"],
        "classifier_name": c_recipe["name"],
        "classifier_family": c_recipe["family"],
        "classifier_complexity": c_recipe.get("complexity", "low"),
        "pipeline_id": f"{v_recipe['id']}__{c_recipe['id']}",
    }

    try:
        pipeline = make_pipeline(v_recipe, c_recipe)

        start_train = time.time()
        pipeline.fit(X_train, y_train)
        train_time = time.time() - start_train

        start_pred = time.time()
        y_pred = pipeline.predict(X_test)
        pred_time = time.time() - start_pred

        acc = accuracy_score(y_test, y_pred)
        macro_f1 = f1_score(y_test, y_pred, average="macro", zero_division=0)
        weighted_f1 = f1_score(y_test, y_pred, average="weighted", zero_division=0)
        precision_macro = precision_score(y_test, y_pred, average="macro", zero_division=0)
        recall_macro = recall_score(y_test, y_pred, average="macro", zero_division=0)
        size_kb = estimate_model_size_kb(pipeline)

        # Simple scoring:
        # Performance is important, but efficient/simple models get rewarded too.
        performance_score = (macro_f1 * 60) + (acc * 25) + (weighted_f1 * 15)

        # Efficiency score rewards fast/small models.
        speed_score = max(0, 100 - (train_time * 10) - (pred_time * 100))
        size_score = max(0, 100 - (size_kb / 20)) if not np.isnan(size_kb) else 50
        efficiency_score = (speed_score * 0.6) + (size_score * 0.4)

        # Suitability rewards simpler models unless heavy models strongly outperform.
        penalty = complexity_penalty(v_recipe, c_recipe)
        suitability_score = max(0, 100 - penalty * 15)

        final_score = (
            performance_score * 0.55
            + efficiency_score * 0.20
            + suitability_score * 0.15
            + 100 * 0.10  # basic completion score
        )

        result.update({
            "status": "completed",
            "accuracy": acc,
            "macro_f1": macro_f1,
            "weighted_f1": weighted_f1,
            "precision_macro": precision_macro,
            "recall_macro": recall_macro,
            "train_time_sec": train_time,
            "prediction_time_sec": pred_time,
            "model_size_kb": size_kb,
            "performance_score": performance_score,
            "efficiency_score": efficiency_score,
            "suitability_score": suitability_score,
            "final_score": final_score,
            "error": "",
        })

    except Exception as e:
        result.update({
            "status": "failed",
            "accuracy": np.nan,
            "macro_f1": np.nan,
            "weighted_f1": np.nan,
            "precision_macro": np.nan,
            "recall_macro": np.nan,
            "train_time_sec": np.nan,
            "prediction_time_sec": np.nan,
            "model_size_kb": np.nan,
            "performance_score": 0,
            "efficiency_score": 0,
            "suitability_score": 0,
            "final_score": 0,
            "error": str(e),
        })

    return result

all_results = []
total_runs = len(vectorizer_recipes) * len(classifier_recipes)
print(f"Running {total_runs} pipelines...")

for v in vectorizer_recipes:
    for c in classifier_recipes:
        print(f"Training: {v['id']} + {c['id']}")
        result = run_single_pipeline(v, c, X_train_80, X_test_80, y_train_80, y_test_80)
        all_results.append(result)

results_80 = pd.DataFrame(all_results).sort_values("final_score", ascending=False).reset_index(drop=True)
results_80.insert(0, "rank", range(1, len(results_80) + 1))

print("Done.")
display(results_80)
# Out:
# Running 100 pipelines...
# Training: count_word + multinomial_nb
# Training: count_word + complement_nb
# Training: count_word + bernoulli_nb
# Training: count_word + logreg_balanced
# Training: count_word + ridge_classifier
# Training: count_word + linear_svc
# Training: count_word + sgd_log
# Training: count_word + sgd_hinge
# Training: count_word + passive_aggressive
# Training: count_word + random_forest_small
# Training: count_binary + multinomial_nb
# Training: count_binary + complement_nb
# Training: count_binary + bernoulli_nb
# Training: count_binary + logreg_balanced
# Training: count_binary + ridge_classifier
# Training: count_binary + linear_svc
# Training: count_binary + sgd_log
# Training: count_binary + sgd_hinge
# Training: count_binary + passive_aggressive
# Training: count_binary + random_forest_small
# Training: count_bigram + multinomial_nb
# Training: count_bigram + complement_nb
# Training: count_bigram + bernoulli_nb
# Training: count_bigram + logreg_balanced
# Training: count_bigram + ridge_classifier
# Training: count_bigram + linear_svc
# Training: count_bigram + sgd_log
# Training: count_bigram + sgd_hinge
# Training: count_bigram + passive_aggressive
# Training: count_bigram + random_forest_small
# Training: tfidf_word + multinomial_nb
# Training: tfidf_word + complement_nb
# Training: tfidf_word + bernoulli_nb
# Training: tfidf_word + logreg_balanced
# Training: tfidf_word + ridge_classifier
# Training: tfidf_word + linear_svc
# Training: tfidf_word + sgd_log
# Training: tfidf_word + sgd_hinge
# Training: tfidf_word + passive_aggressive
# Training: tfidf_word + random_forest_small
# Training: tfidf_bigram + multinomial_nb
# Training: tfidf_bigram + complement_nb
# Training: tfidf_bigram + bernoulli_nb
# Training: tfidf_bigram + logreg_balanced
# Training: tfidf_bigram + ridge_classifier
# Training: tfidf_bigram + linear_svc
# Training: tfidf_bigram + sgd_log
# Training: tfidf_bigram + sgd_hinge
# Training: tfidf_bigram + passive_aggressive
# Training: tfidf_bigram + random_forest_small
# Training: tfidf_char + multinomial_nb
# Training: tfidf_char + complement_nb
# Training: tfidf_char + bernoulli_nb
# Training: tfidf_char + logreg_balanced
# Training: tfidf_char + ridge_classifier
# Training: tfidf_char + linear_svc
# Training: tfidf_char + sgd_log
# Training: tfidf_char + sgd_hinge
# Training: tfidf_char + passive_aggressive
# Training: tfidf_char + random_forest_small
# Training: tfidf_char_wb + multinomial_nb
# Training: tfidf_char_wb + complement_nb
# Training: tfidf_char_wb + bernoulli_nb
# Training: tfidf_char_wb + logreg_balanced
# Training: tfidf_char_wb + ridge_classifier
# Training: tfidf_char_wb + linear_svc
# Training: tfidf_char_wb + sgd_log
# Training: tfidf_char_wb + sgd_hinge
# Training: tfidf_char_wb + passive_aggressive
# Training: tfidf_char_wb + random_forest_small
# Training: hashing_word + multinomial_nb
# Training: hashing_word + complement_nb
# Training: hashing_word + bernoulli_nb
# Training: hashing_word + logreg_balanced
# Training: hashing_word + ridge_classifier
# Training: hashing_word + linear_svc
# Training: hashing_word + sgd_log
# Training: hashing_word + sgd_hinge
# Training: hashing_word + passive_aggressive
# Training: hashing_word + random_forest_small
# Training: hashing_char + multinomial_nb
# Training: hashing_char + complement_nb
# Training: hashing_char + bernoulli_nb
# Training: hashing_char + logreg_balanced
# Training: hashing_char + ridge_classifier
# Training: hashing_char + linear_svc
# Training: hashing_char + sgd_log
# Training: hashing_char + sgd_hinge
# Training: hashing_char + passive_aggressive
# Training: hashing_char + random_forest_small
# Training: tfidf_svd + multinomial_nb
# Training: tfidf_svd + complement_nb
# Training: tfidf_svd + bernoulli_nb
# Training: tfidf_svd + logreg_balanced
# Training: tfidf_svd + ridge_classifier
# Training: tfidf_svd + linear_svc
# Training: tfidf_svd + sgd_log
# Training: tfidf_svd + sgd_hinge
# Training: tfidf_svd + passive_aggressive
# Training: tfidf_svd + random_forest_small
# Done.
#     rank vectorizer_id         vectorizer_name         vectorizer_family  \
# 0      1  count_binary  Binary CountVectorizer              count_binary
# 1      2  count_binary  Binary CountVectorizer              count_binary
# 2      3    count_word    CountVectorizer Word                     count
# 3      4  count_binary  Binary CountVectorizer              count_binary
# 4      5    count_word    CountVectorizer Word                     count
# ..   ...           ...                     ...                       ...
# 95    96     tfidf_svd            TF-IDF + SVD  dimensionality_reduction
# 96    97     tfidf_svd            TF-IDF + SVD  dimensionality_reduction
# 97    98     tfidf_svd            TF-IDF + SVD  dimensionality_reduction
# 98    99     tfidf_svd            TF-IDF + SVD  dimensionality_reduction
# 99   100     tfidf_svd            TF-IDF + SVD  dimensionality_reduction
#
#    vectorizer_complexity        classifier_id                classifier_name  \
# 0                    low     ridge_classifier               Ridge Classifier
# 1                    low        complement_nb         Complement Naive Bayes
# 2                    low        complement_nb         Complement Naive Bayes
# 3                    low           linear_svc                      LinearSVC
# 4                    low      logreg_balanced   Logistic Regression Balanced
# ..                   ...                  ...                            ...
# 95                  high  random_forest_small            Small Random Forest
# 96                  high         bernoulli_nb          Bernoulli Naive Bayes
# 97                  high              sgd_log    SGDClassifier Logistic Loss
# 98                  high   passive_aggressive  Passive Aggressive Classifier
# 99                  high            sgd_hinge       SGDClassifier Hinge Loss
#
#    classifier_family classifier_complexity                     pipeline_id  \
# 0             linear                   low  count_binary__ridge_classifier
# 1        naive_bayes                   low     count_binary__complement_nb
# 2        naive_bayes                   low       count_word__complement_nb
# 3       margin_based                medium        count_binary__linear_svc
# 4             linear                   low     count_word__logreg_balanced
# ..               ...                   ...                             ...
# 95        tree_based                  high  tfidf_svd__random_forest_small
# 96       naive_bayes                   low         tfidf_svd__bernoulli_nb
# 97               sgd                medium              tfidf_svd__sgd_log
# 98     online_margin                medium   tfidf_svd__passive_aggressive
# 99               sgd                medium            tfidf_svd__sgd_hinge
#
#     ... precision_macro  recall_macro  train_time_sec  prediction_time_sec  \
# 0   ...        0.783333      0.761905        0.011022             0.001223
# 1   ...        0.694048      0.714286        0.003802             0.000784
# 2   ...        0.688095      0.714286        0.005925             0.001123
# 3   ...        0.737374      0.714286        0.005192             0.001105
# 4   ...        0.666667      0.666667        0.015032             0.001182
# ..  ...             ...           ...             ...                  ...
# 95  ...        0.301515      0.341270        0.164500             0.005942
# 96  ...        0.116667      0.333333        0.050132             0.007613
# 97  ...        0.197802      0.317460        0.022895             0.005276
# 98  ...        0.197802      0.317460        0.045262             0.005438
# 99  ...        0.197802      0.317460        0.055407             0.007381
#
#     model_size_kb  performance_score  efficiency_score  suitability_score  \
# 0       16.567383          74.846257         99.529123                100
# 1       25.864258          69.573718         99.412869                100
# 2       25.864258          69.160714         99.379790                100
# 3       16.511719          68.933333         99.572338                 85
# 4       16.687500          64.784759         99.505147                100
# ..            ...                ...               ...                ...
# 95            NaN          31.823232         78.656456                 40
# 96            NaN          21.842593         79.242445                 70
# 97            NaN          25.030075         79.546059                 55
# 98            NaN          25.030075         79.402174                 55
# 99            NaN          25.030075         79.224689                 55
#
#     final_score  error
# 0     86.071266
# 1     83.148119
# 2     82.914351
# 3     80.577801
# 4     80.532647
# ..          ...    ...
# 95    49.234069
# 96    48.361915
# 97    47.925753
# 98    47.896976
# 99    47.861479
#
# [100 rows x 24 columns]

# %%
# ============================================================
# STEP 8: Save and inspect 80R results
# ============================================================

results_80.to_csv("results_80R.csv", index=False)
print("Saved: results_80R.csv")

print("\nTop 10 pipelines by final_score:")
display(results_80.head(10)[[
    "rank",
    "pipeline_id",
    "accuracy",
    "macro_f1",
    "weighted_f1",
    "train_time_sec",
    "model_size_kb",
    "final_score",
    "status",
]])

print("\nFailed pipelines, if any:")
display(results_80[results_80["status"] == "failed"][["pipeline_id", "error"]])
# Out:
# Saved: results_80R.csv
#
# Top 10 pipelines by final_score:
#    rank                        pipeline_id  accuracy  macro_f1  weighted_f1  \
# 0     1     count_binary__ridge_classifier      0.75  0.750446     0.737968
# 1     2        count_binary__complement_nb      0.70  0.696581     0.685256
# 2     3          count_word__complement_nb      0.70  0.690476     0.682143
# 3     4           count_binary__linear_svc      0.70  0.688889     0.673333
# 4     5        count_word__logreg_balanced      0.65  0.650624     0.633155
# 5     6      count_binary__logreg_balanced      0.65  0.650624     0.633155
# 6     7       count_binary__multinomial_nb      0.65  0.642857     0.632143
# 7     8    count_word__random_forest_small      0.75  0.727096     0.713450
# 8     9  tfidf_bigram__random_forest_small      0.75  0.715100     0.704701
# 9    10           count_word__bernoulli_nb      0.65  0.603989     0.588034
#
#    train_time_sec  model_size_kb  final_score     status
# 0        0.011022      16.567383    86.071266  completed
# 1        0.003802      25.864258    83.148119  completed
# 2        0.005925      25.864258    82.914351  completed
# 3        0.005192      16.511719    80.577801  completed
# 4        0.015032      16.687500    80.532647  completed
# 5        0.011749      16.687500    80.529841  completed
# 6        0.003871      23.458008    80.259692  completed
# 7        0.081464     161.452148    79.858592  completed
# 8        0.134875     160.543945    79.321000  completed
# 9        0.003656      23.473633    78.609962  completed
# Failed pipelines, if any:
# Empty DataFrame
# Columns: [pipeline_id, error]
# Index: []

# %%
# ============================================================
# STEP 9: Visual analytics
# ============================================================

completed = results_80[results_80["status"] == "completed"].copy()

if completed.empty:
    print("No completed models to visualize.")
else:
    top_plot = completed.sort_values("final_score", ascending=False).head(10)

    plt.figure(figsize=(10, 5))
    plt.barh(top_plot["pipeline_id"][::-1], top_plot["final_score"][::-1])
    plt.xlabel("Final Score")
    plt.title("Top 10 Pipelines by Final Score")
    plt.tight_layout()
    plt.show()

    family_perf = completed.groupby("vectorizer_family")[["macro_f1", "accuracy", "final_score"]].mean().sort_values("final_score", ascending=False)
    print("Average performance by vectorizer family:")
    display(family_perf)

    clf_perf = completed.groupby("classifier_family")[["macro_f1", "accuracy", "final_score"]].mean().sort_values("final_score", ascending=False)
    print("Average performance by classifier family:")
    display(clf_perf)
# Out:
# Average performance by vectorizer family:
#                           macro_f1  accuracy  final_score
# vectorizer_family
# count_binary              0.650189     0.670    79.389050
# count                     0.615101     0.630    77.394308
# tfidf                     0.563238     0.570    74.420582
# hashing                   0.560694     0.585    72.108704
# count_ngram               0.504280     0.515    71.154480
# char_hashing              0.526405     0.570    70.265380
# char_tfidf                0.450122     0.470    64.865935
# char_wb_tfidf             0.444527     0.455    64.858106
# tfidf_ngram               0.380300     0.390    64.350027
# dimensionality_reduction  0.292587     0.345    51.842653
# Average performance by classifier family:
#                    macro_f1  accuracy  final_score
# classifier_family
# tree_based         0.639809  0.660000    73.244277
# linear             0.520714  0.525000    71.437418
# margin_based       0.527245  0.535000    69.659348
# naive_bayes        0.469736  0.506667    68.992328
# sgd                0.458318  0.482500    66.094331
# online_margin      0.453115  0.470000    65.705118

# %% [markdown]
# # STEP 10: Understand one selected pipeline
#
# Use this section to inspect the confusion matrix and classification report of a pipeline.
#
# By default, it chooses the top-ranked pipeline.
# You can change `SELECTED_PIPELINE_ID` to any pipeline from `results_80`.

# %%
# ============================================================
# STEP 10A: Detailed report for one pipeline
# ============================================================

SELECTED_PIPELINE_ID = results_80.iloc[0]["pipeline_id"]  # change this if needed

selected_row = results_80[results_80["pipeline_id"] == SELECTED_PIPELINE_ID].iloc[0]
v_recipe = next(v for v in vectorizer_recipes if v["id"] == selected_row["vectorizer_id"])
c_recipe = next(c for c in classifier_recipes if c["id"] == selected_row["classifier_id"])

pipeline = make_pipeline(v_recipe, c_recipe)
pipeline.fit(X_train_80, y_train_80)
y_pred = pipeline.predict(X_test_80)

print("Selected pipeline:", SELECTED_PIPELINE_ID)
print("\nClassification report:")
print(classification_report(y_test_80, y_pred, zero_division=0))

labels = sorted(y.unique())
cm = confusion_matrix(y_test_80, y_pred, labels=labels)
cm_df = pd.DataFrame(cm, index=[f"actual_{l}" for l in labels], columns=[f"pred_{l}" for l in labels])
display(cm_df)
# Out:
# Selected pipeline: count_binary__ridge_classifier
#
# Classification report:
#               precision    recall  f1-score   support
#
#     negative       0.75      0.43      0.55         7
#      neutral       1.00      1.00      1.00         6
#     positive       0.60      0.86      0.71         7
#
#     accuracy                           0.75        20
#    macro avg       0.78      0.76      0.75        20
# weighted avg       0.77      0.75      0.74        20
#                  pred_negative  pred_neutral  pred_positive
# actual_negative              3             0              4
# actual_neutral               0             6              0
# actual_positive              1             0              6

# %% [markdown]
# # STEP 11: Shortlist candidates for the 300R round
#
# The notebook will suggest candidates using two ideas:
#
# 1. Top pipelines by score.
# 2. Best representative from each vectorizer/classifier family.
#
# This helps avoid the mistake of selecting only one type of model.

# %%
# ============================================================
# STEP 11A: Candidate shortlist
# ============================================================

def make_candidate_shortlist(results_df, top_n=8):
    completed = results_df[results_df["status"] == "completed"].copy()
    if completed.empty:
        return completed

    top_overall = completed.sort_values("final_score", ascending=False).head(top_n)

    best_by_vectorizer_family = (
        completed.sort_values("final_score", ascending=False)
        .groupby("vectorizer_family")
        .head(1)
    )

    best_by_classifier_family = (
        completed.sort_values("final_score", ascending=False)
        .groupby("classifier_family")
        .head(1)
    )

    shortlist = pd.concat([top_overall, best_by_vectorizer_family, best_by_classifier_family])
    shortlist = shortlist.drop_duplicates(subset=["pipeline_id"])
    shortlist = shortlist.sort_values("final_score", ascending=False).reset_index(drop=True)
    shortlist.insert(0, "candidate_rank", range(1, len(shortlist) + 1))
    return shortlist

candidate_shortlist = make_candidate_shortlist(results_80, top_n=8)

print("Candidate shortlist for 300R round:")
display(candidate_shortlist[[
    "candidate_rank",
    "pipeline_id",
    "vectorizer_family",
    "classifier_family",
    "accuracy",
    "macro_f1",
    "final_score"
]])
# Out:
# Candidate shortlist for 300R round:
#     candidate_rank                         pipeline_id  \
# 0                1      count_binary__ridge_classifier
# 1                2         count_binary__complement_nb
# 2                3           count_word__complement_nb
# 3                4            count_binary__linear_svc
# 4                5         count_word__logreg_balanced
# 5                6       count_binary__logreg_balanced
# 6                7        count_binary__multinomial_nb
# 7                8     count_word__random_forest_small
# 8                9   tfidf_bigram__random_forest_small
# 9               10            tfidf_word__bernoulli_nb
# 10              11      hashing_word__ridge_classifier
# 11              12  tfidf_char_wb__random_forest_small
# 12              13             count_binary__sgd_hinge
# 13              14    count_binary__passive_aggressive
# 14              15          count_bigram__bernoulli_nb
# 15              16      hashing_char__ridge_classifier
# 16              17     tfidf_char__random_forest_small
# 17              18         tfidf_svd__ridge_classifier
#
#            vectorizer_family classifier_family  accuracy  macro_f1  \
# 0               count_binary            linear      0.75  0.750446
# 1               count_binary       naive_bayes      0.70  0.696581
# 2                      count       naive_bayes      0.70  0.690476
# 3               count_binary      margin_based      0.70  0.688889
# 4                      count            linear      0.65  0.650624
# 5               count_binary            linear      0.65  0.650624
# 6               count_binary       naive_bayes      0.65  0.642857
# 7                      count        tree_based      0.75  0.727096
# 8                tfidf_ngram        tree_based      0.75  0.715100
# 9                      tfidf       naive_bayes      0.65  0.603989
# 10                   hashing            linear      0.65  0.650624
# 11             char_wb_tfidf        tree_based      0.75  0.750446
# 12              count_binary               sgd      0.65  0.617934
# 13              count_binary     online_margin      0.65  0.603989
# 14               count_ngram       naive_bayes      0.60  0.547980
# 15              char_hashing            linear      0.65  0.590741
# 16                char_tfidf        tree_based      0.70  0.708333
# 17  dimensionality_reduction            linear      0.45  0.460684
#
#     final_score
# 0     86.071266
# 1     83.148119
# 2     82.914351
# 3     80.577801
# 4     80.532647
# 5     80.529841
# 6     80.259692
# 7     79.858592
# 8     79.321000
# 9     78.595737
# 10    78.154472
# 11    77.990815
# 12    76.929243
# 13    76.387022
# 14    75.506492
# 15    75.502538
# 16    75.409834
# 17    61.583726

# %% [markdown]
# # STEP 12: Optional 300R round
#
# Use this only after you have a 300-row dataset.
#
# The notebook tries these options:
#
# 1. If you upload or place `ipl_300R_indian_english_sentiment_dataset.csv` next to the notebook, it will load it.
# 2. If you put the 300R dataset in GitHub later, paste the raw GitHub URL into `DATA_URL_300R`.
# 3. If you do not have 300R yet, skip this section.
#
# Expected 300R columns can be either:
#
# - `tweet`, `subject_keyword`, `sentiment`
# - or `statement`, `subject_keyword`, `sentiment`
#
# If the column is `tweet`, the notebook renames it to `statement`.

# %%
# ============================================================
# STEP 12A: Load optional 300R dataset
# ============================================================

LOCAL_DATA_PATH_300R = "/content/ipl_sentiment_380r.csv"

def load_optional_300R():
    if Path(LOCAL_DATA_PATH_300R).exists():
        df = pd.read_csv(LOCAL_DATA_PATH_300R)
        print("Loaded local dataset:", LOCAL_DATA_PATH_300R)
        return df

    print("No 300R/380R dataset found. You can skip this section for now.")
    return None

df_300 = load_optional_300R()

if df_300 is not None:

    df_300 = df_300.rename(columns={
        "Post text": "statement",
        "Post Keyword": "subject_keyword",
        "Sentiment": "sentiment"
    })

    missing = [col for col in required_columns if col not in df_300.columns]
    if missing:
        raise ValueError(f"Dataset is missing required columns: {missing}")

    df_300 = df_300.dropna(subset=required_columns).copy()
    df_300["statement"] = df_300["statement"].astype(str)
    df_300["subject_keyword"] = df_300["subject_keyword"].astype(str)
    df_300["sentiment"] = df_300["sentiment"].astype(str).str.lower().str.strip()

    df_300["model_text"] = (
        df_300["subject_keyword"] + " [SEP] " + df_300["statement"]
    )

    print("Dataset shape:", df_300.shape)
    display(df_300.head())
    display(df_300["sentiment"].value_counts())
# Out:
# Loaded local dataset: /content/ipl_sentiment_380r.csv
# Dataset shape: (379, 5)
#    S.no                                          statement subject_keyword  \
# 0     1  Dj and Rayudu Bond Peak male content #CSK #dho...             CSK
# 1     2  Slower One delivery from Nathan Ellis #CSK #RC...             CSK
# 2     3  We used to own RCB with finished Uthappa and D...             CSK
# 3     4  That Overton anger costed us FairPlay Award. #...             CSK
# 4     5  Here is what R Ashwin said on live: "PRASANNA ...             CSK
#
#   sentiment                                         model_text
# 0  positive  CSK [SEP] Dj and Rayudu Bond Peak male content...
# 1   neutral  CSK [SEP] Slower One delivery from Nathan Elli...
# 2  negative  CSK [SEP] We used to own RCB with finished Uth...
# 3   neutral  CSK [SEP] That Overton anger costed us FairPla...
# 4   neutral  CSK [SEP] Here is what R Ashwin said on live: ...
# sentiment
# neutral     210
# positive    150
# negative     19
# Name: count, dtype: int64

# %%
# ============================================================
# STEP 12B: Run 6x6 shortlisted pipelines on 300R
# ============================================================

if df_300 is None:
    print("Skipping 300R experiment because no 300R dataset was loaded.")
    results_300 = pd.DataFrame()

else:
    X_300 = df_300["model_text"]
    y_300 = df_300["sentiment"]

    X_train_300, X_test_300, y_train_300, y_test_300 = train_test_split(
        X_300,
        y_300,
        test_size=0.25,
        random_state=RANDOM_STATE,
        stratify=y_300
    )

    # -------------------------
    # Best 6 vectorizers
    # -------------------------
    selected_vectorizer_ids_for_300R = [
        "count_binary",
        "count_word",
        "tfidf_word",
        "hashing_word",
        "count_bigram",
        "hashing_char"
    ]

    # -------------------------
    # Best 6 classifiers
    # -------------------------
    selected_classifier_ids_for_300R = [
        "ridge_classifier",
        "complement_nb",
        "bernoulli_nb",
        "logreg_balanced",
        "linear_svc",
        "random_forest_small"
    ]

    results_300_list = []

    total_runs = (
        len(selected_vectorizer_ids_for_300R)
        * len(selected_classifier_ids_for_300R)
    )

    print(f"Running {total_runs} pipelines on 300R...")

    for v_id in selected_vectorizer_ids_for_300R:

        v_recipe = next(
            v for v in vectorizer_recipes
            if v["id"] == v_id
        )

        for c_id in selected_classifier_ids_for_300R:

            c_recipe = next(
                c for c in classifier_recipes
                if c["id"] == c_id
            )

            print(f"300R training: {v_id} + {c_id}")

            result = run_single_pipeline(
                v_recipe,
                c_recipe,
                X_train_300,
                X_test_300,
                y_train_300,
                y_test_300
            )

            results_300_list.append(result)

    results_300 = (
        pd.DataFrame(results_300_list)
        .sort_values("final_score", ascending=False)
        .reset_index(drop=True)
    )

    results_300.insert(
        0,
        "rank_300R",
        range(1, len(results_300) + 1)
    )

    results_300.to_csv("results_300R.csv", index=False)

    print("Saved: results_300R.csv")
    display(results_300)
# Out:
# Running 36 pipelines on 300R...
# 300R training: count_binary + ridge_classifier
# 300R training: count_binary + complement_nb
# 300R training: count_binary + bernoulli_nb
# 300R training: count_binary + logreg_balanced
# 300R training: count_binary + linear_svc
# 300R training: count_binary + random_forest_small
# 300R training: count_word + ridge_classifier
# 300R training: count_word + complement_nb
# 300R training: count_word + bernoulli_nb
# 300R training: count_word + logreg_balanced
# 300R training: count_word + linear_svc
# 300R training: count_word + random_forest_small
# 300R training: tfidf_word + ridge_classifier
# 300R training: tfidf_word + complement_nb
# 300R training: tfidf_word + bernoulli_nb
# 300R training: tfidf_word + logreg_balanced
# 300R training: tfidf_word + linear_svc
# 300R training: tfidf_word + random_forest_small
# 300R training: hashing_word + ridge_classifier
# 300R training: hashing_word + complement_nb
# 300R training: hashing_word + bernoulli_nb
# 300R training: hashing_word + logreg_balanced
# 300R training: hashing_word + linear_svc
# 300R training: hashing_word + random_forest_small
# 300R training: count_bigram + ridge_classifier
# 300R training: count_bigram + complement_nb
# 300R training: count_bigram + bernoulli_nb
# 300R training: count_bigram + logreg_balanced
# 300R training: count_bigram + linear_svc
# 300R training: count_bigram + random_forest_small
# 300R training: hashing_char + ridge_classifier
# 300R training: hashing_char + complement_nb
# 300R training: hashing_char + bernoulli_nb
# 300R training: hashing_char + logreg_balanced
# 300R training: hashing_char + linear_svc
# 300R training: hashing_char + random_forest_small
# Saved: results_300R.csv
#     rank_300R vectorizer_id              vectorizer_name vectorizer_family  \
# 0           1  count_binary       Binary CountVectorizer      count_binary
# 1           2    count_word         CountVectorizer Word             count
# 2           3    tfidf_word                  TF-IDF Word             tfidf
# 3           4    count_word         CountVectorizer Word             count
# 4           5  count_bigram    CountVectorizer 1-2 grams       count_ngram
# 5           6  count_binary       Binary CountVectorizer      count_binary
# 6           7    tfidf_word                  TF-IDF Word             tfidf
# 7           8  count_binary       Binary CountVectorizer      count_binary
# 8           9  count_bigram    CountVectorizer 1-2 grams       count_ngram
# 9          10    tfidf_word                  TF-IDF Word             tfidf
# 10         11    count_word         CountVectorizer Word             count
# 11         12    count_word         CountVectorizer Word             count
# 12         13  count_binary       Binary CountVectorizer      count_binary
# 13         14    tfidf_word                  TF-IDF Word             tfidf
# 14         15  count_bigram    CountVectorizer 1-2 grams       count_ngram
# 15         16    count_word         CountVectorizer Word             count
# 16         17  count_binary       Binary CountVectorizer      count_binary
# 17         18    tfidf_word                  TF-IDF Word             tfidf
# 18         19  count_bigram    CountVectorizer 1-2 grams       count_ngram
# 19         20  hashing_word       HashingVectorizer Word           hashing
# 20         21  hashing_word       HashingVectorizer Word           hashing
# 21         22  hashing_word       HashingVectorizer Word           hashing
# 22         23  hashing_char  HashingVectorizer Character      char_hashing
# 23         24  hashing_char  HashingVectorizer Character      char_hashing
# 24         25  hashing_word       HashingVectorizer Word           hashing
# 25         26  hashing_word       HashingVectorizer Word           hashing
# 26         27  hashing_char  HashingVectorizer Character      char_hashing
# 27         28  hashing_char  HashingVectorizer Character      char_hashing
# 28         29  count_bigram    CountVectorizer 1-2 grams       count_ngram
# 29         30  hashing_char  HashingVectorizer Character      char_hashing
# 30         31  count_binary       Binary CountVectorizer      count_binary
# 31         32    count_word         CountVectorizer Word             count
# 32         33  hashing_word       HashingVectorizer Word           hashing
# 33         34  count_bigram    CountVectorizer 1-2 grams       count_ngram
# 34         35    tfidf_word                  TF-IDF Word             tfidf
# 35         36  hashing_char  HashingVectorizer Character      char_hashing
#
#    vectorizer_complexity        classifier_id               classifier_name  \
# 0                    low      logreg_balanced  Logistic Regression Balanced
# 1                    low        complement_nb        Complement Naive Bayes
# 2                    low        complement_nb        Complement Naive Bayes
# 3                    low     ridge_classifier              Ridge Classifier
# 4                    low        complement_nb        Complement Naive Bayes
# 5                    low     ridge_classifier              Ridge Classifier
# 6                    low     ridge_classifier              Ridge Classifier
# 7                    low        complement_nb        Complement Naive Bayes
# 8                    low     ridge_classifier              Ridge Classifier
# 9                    low      logreg_balanced  Logistic Regression Balanced
# 10                   low           linear_svc                     LinearSVC
# 11                   low      logreg_balanced  Logistic Regression Balanced
# 12                   low           linear_svc                     LinearSVC
# 13                   low           linear_svc                     LinearSVC
# 14                   low      logreg_balanced  Logistic Regression Balanced
# 15                   low         bernoulli_nb         Bernoulli Naive Bayes
# 16                   low         bernoulli_nb         Bernoulli Naive Bayes
# 17                   low         bernoulli_nb         Bernoulli Naive Bayes
# 18                   low           linear_svc                     LinearSVC
# 19                medium      logreg_balanced  Logistic Regression Balanced
# 20                medium     ridge_classifier              Ridge Classifier
# 21                medium        complement_nb        Complement Naive Bayes
# 22                medium      logreg_balanced  Logistic Regression Balanced
# 23                medium     ridge_classifier              Ridge Classifier
# 24                medium           linear_svc                     LinearSVC
# 25                medium         bernoulli_nb         Bernoulli Naive Bayes
# 26                medium        complement_nb        Complement Naive Bayes
# 27                medium           linear_svc                     LinearSVC
# 28                   low         bernoulli_nb         Bernoulli Naive Bayes
# 29                medium         bernoulli_nb         Bernoulli Naive Bayes
# 30                   low  random_forest_small           Small Random Forest
# 31                   low  random_forest_small           Small Random Forest
# 32                medium  random_forest_small           Small Random Forest
# 33                   low  random_forest_small           Small Random Forest
# 34                   low  random_forest_small           Small Random Forest
# 35                medium  random_forest_small           Small Random Forest
#
#    classifier_family classifier_complexity                        pipeline_id  \
# 0             linear                   low      count_binary__logreg_balanced
# 1        naive_bayes                   low          count_word__complement_nb
# 2        naive_bayes                   low          tfidf_word__complement_nb
# 3             linear                   low       count_word__ridge_classifier
# 4        naive_bayes                   low        count_bigram__complement_nb
# 5             linear                   low     count_binary__ridge_classifier
# 6             linear                   low       tfidf_word__ridge_classifier
# 7        naive_bayes                   low        count_binary__complement_nb
# 8             linear                   low     count_bigram__ridge_classifier
# 9             linear                   low        tfidf_word__logreg_balanced
# 10      margin_based                medium             count_word__linear_svc
# 11            linear                   low        count_word__logreg_balanced
# 12      margin_based                medium           count_binary__linear_svc
# 13      margin_based                medium             tfidf_word__linear_svc
# 14            linear                   low      count_bigram__logreg_balanced
# 15       naive_bayes                   low           count_word__bernoulli_nb
# 16       naive_bayes                   low         count_binary__bernoulli_nb
# 17       naive_bayes                   low           tfidf_word__bernoulli_nb
# 18      margin_based                medium           count_bigram__linear_svc
# 19            linear                   low      hashing_word__logreg_balanced
# 20            linear                   low     hashing_word__ridge_classifier
# 21       naive_bayes                   low        hashing_word__complement_nb
# 22            linear                   low      hashing_char__logreg_balanced
# 23            linear                   low     hashing_char__ridge_classifier
# 24      margin_based                medium           hashing_word__linear_svc
# 25       naive_bayes                   low         hashing_word__bernoulli_nb
# 26       naive_bayes                   low        hashing_char__complement_nb
# 27      margin_based                medium           hashing_char__linear_svc
# 28       naive_bayes                   low         count_bigram__bernoulli_nb
# 29       naive_bayes                   low         hashing_char__bernoulli_nb
# 30        tree_based                  high  count_binary__random_forest_small
# 31        tree_based                  high    count_word__random_forest_small
# 32        tree_based                  high  hashing_word__random_forest_small
# 33        tree_based                  high  count_bigram__random_forest_small
# 34        tree_based                  high    tfidf_word__random_forest_small
# 35        tree_based                  high  hashing_char__random_forest_small
#
#     ... precision_macro  recall_macro  train_time_sec  prediction_time_sec  \
# 0   ...        0.495032      0.525412        0.051444             0.005394
# 1   ...        0.488257      0.517423        0.012772             0.003029
# 2   ...        0.479000      0.511984        0.013127             0.003435
# 3   ...        0.473030      0.500255        0.031081             0.003325
# 4   ...        0.485803      0.520993        0.039222             0.008641
# 5   ...        0.466270      0.492096        0.027423             0.003247
# 6   ...        0.460741      0.491246        0.033963             0.005892
# 7   ...        0.477273      0.502125        0.016439             0.003866
# 8   ...        0.459091      0.485807        0.050865             0.005156
# 9   ...        0.461230      0.490396        0.040119             0.006001
# 10  ...        0.488527      0.518273        0.026442             0.005401
# 11  ...        0.451465      0.475948        0.062258             0.005363
# 12  ...        0.480729      0.510114        0.033884             0.006250
# 13  ...        0.468648      0.500255        0.024698             0.005712
# 14  ...        0.431647      0.457930        0.200143             0.009559
# 15  ...        0.444847      0.433452        0.012775             0.003499
# 16  ...        0.444847      0.433452        0.021105             0.005914
# 17  ...        0.444847      0.433452        0.013593             0.003915
# 18  ...        0.445343      0.473228        0.031296             0.004904
# 19  ...        0.461957      0.445351        0.037955             0.004998
# 20  ...        0.429825      0.452490        0.015204             0.003000
# 21  ...        0.429692      0.449771        0.008526             0.002914
# 22  ...        0.441489      0.469658        0.373531             0.042571
# 23  ...        0.428083      0.449771        0.084780             0.022651
# 24  ...        0.452123      0.479517        0.017392             0.004909
# 25  ...        0.423051      0.435322        0.008492             0.003260
# 26  ...        0.414848      0.429033        0.066045             0.034534
# 27  ...        0.429470      0.455210        0.123139             0.022416
# 28  ...        0.395833      0.376679        0.027994             0.005455
# 29  ...        0.391156      0.405745        0.065778             0.024049
# 30  ...        0.444847      0.433452        0.100730             0.007230
# 31  ...        0.430509      0.429883        0.100103             0.007253
# 32  ...        0.455156      0.454190        0.131567             0.007110
# 33  ...        0.429429      0.415434        0.122475             0.008997
# 34  ...        0.421111      0.406425        0.106578             0.007582
# 35  ...        0.427619      0.427163        0.259032             0.031535
#
#     model_size_kb  performance_score  efficiency_score  suitability_score  \
# 0      116.656250          60.170671         97.034572                100
# 1      186.848633          57.762783         96.004676                100
# 2      204.399414          57.729770         95.627130                100
# 3      116.536133          57.067841         97.283320                100
# 4      342.801758          58.593907         92.390188                100
# 5      116.536133          56.654400         97.309920                100
# 6      134.211914          55.948727         96.758459                100
# 7      186.848633          56.088039         95.932405                100
# 8      217.754883          55.833878         95.030350                100
# 9      134.300781          55.196937         96.713212                100
# 10     116.480469          58.808171         97.187697                 85
# 11     116.656250          54.499312         96.971562                100
# 12     116.480469          58.451486         97.092076                 85
# 13     134.156250          56.827172         96.825962                 85
# 14     217.859375          52.500523         93.868432                100
# 15     169.192383          50.977404         96.329577                100
# 16     169.192383          50.977404         96.134682                100
# 17     186.790039          50.977404         95.947750                100
# 18     217.699219          54.191721         95.164011                 85
# 19      49.500977          52.628541         98.482361                 85
# 20      49.430664          52.281404         98.740146                 85
# 21     113.399414          52.155011         97.506035                 85
# 22      97.469727          53.414762         93.255183                 85
# 23      97.415039          52.127074         96.183959                 85
# 24      49.356445          55.013117         98.614006                 70
# 25      97.352539          50.860880         97.806373                 85
# 26     225.368164          50.074897         93.024301                 85
# 27      97.340820          52.356944         95.969396                 70
# 28     311.473633          43.732048         93.275249                100
# 29     193.321289          46.867408         94.295949                 85
# 30     264.827148          50.977404         93.665275                 70
# 31     268.608398          50.461632         93.592010                 70
# 32     204.181641          53.286334         94.700341                 55
# 33     315.842773          48.815325         92.408447                 70
# 34     276.372070          47.703745         93.378190                 70
# 35     284.087891          50.147874         90.871967                 55
#
#     final_score  error
# 0     77.500783
# 1     75.970466
# 2     75.876800
# 3     75.843977
# 4     75.704687
# 5     75.621904
# 6     75.123492
# 7     75.034902
# 8     74.714703
# 9     74.700958
# 10    74.532033
# 11    74.368934
# 12    74.316733
# 13    73.370137
# 14    72.648974
# 15    72.303487
# 16    72.264508
# 17    72.227122
# 18    71.588249
# 19    71.392170
# 20    71.252801
# 21    70.936463
# 22    70.779156
# 23    70.656683
# 24    70.480015
# 25    70.284758
# 26    68.896053
# 27    68.490199
# 28    67.707676
# 29    67.386264
# 30    67.270627
# 31    66.972300
# 32    66.497552
# 33    65.830118
# 34    65.412698
# 35    64.005724
#
# [36 rows x 24 columns]

# %% [markdown]
# # STEP 13: Select final 4 vectorizers and 4 classifiers
#
# This is the most important submission step.
#
# Rules:
#
# - Select exactly **4 vectorizers**.
# - Select exactly **4 classifiers**.
# - Vectorizers should come from at least **3 different families**.
# - Classifiers should come from at least **3 different families**.
# - Maximum **1 heavy classifier**.
# - Do not select duplicates or near-duplicates.
# - Include at least one simple baseline.
#
# Edit the lists below after reviewing your 80R and 300R results.

# %%
# ============================================================
# STEP 13A: Final selection
# ============================================================

print("Available vectorizers:")
display(pd.DataFrame(vectorizer_recipes)[["id", "name", "family", "complexity", "notes"]])

print("Available classifiers:")
display(pd.DataFrame(classifier_recipes)[["id", "name", "family", "complexity", "notes"]])

FINAL_VECTORIZER_IDS = [
    "count_binary",
    "tfidf_word",
    "hashing_word",
    "count_bigram",
]

FINAL_CLASSIFIER_IDS = [
    "ridge_classifier",
    "complement_nb",
    "logreg_balanced",
    "linear_svc",
]

final_vectorizers = [v for v in vectorizer_recipes if v["id"] in FINAL_VECTORIZER_IDS]
final_classifiers = [c for c in classifier_recipes if c["id"] in FINAL_CLASSIFIER_IDS]

print("Selected vectorizers:", [v["id"] for v in final_vectorizers])
print("Selected classifiers:", [c["id"] for c in final_classifiers])

messages, warnings_list = validate_recipe_diversity(final_vectorizers, final_classifiers)
print("\n".join(messages))

if warnings_list:
    print("\nWarnings:")
    for w in warnings_list:
        print("-", w)
else:
    print("\nFinal diversity check passed.")
# Out:
# Available vectorizers:
#               id                         name                    family  \
# 0     count_word         CountVectorizer Word                     count
# 1   count_binary       Binary CountVectorizer              count_binary
# 2   count_bigram    CountVectorizer 1-2 grams               count_ngram
# 3     tfidf_word                  TF-IDF Word                     tfidf
# 4   tfidf_bigram             TF-IDF 1-2 grams               tfidf_ngram
# 5     tfidf_char             Character TF-IDF                char_tfidf
# 6  tfidf_char_wb          Character WB TF-IDF             char_wb_tfidf
# 7   hashing_word       HashingVectorizer Word                   hashing
# 8   hashing_char  HashingVectorizer Character              char_hashing
# 9      tfidf_svd                 TF-IDF + SVD  dimensionality_reduction
#
#   complexity                                              notes
# 0        low                    Simple word frequency baseline.
# 1        low          Tests word presence instead of frequency.
# 2        low  Captures simple word frequencies and short phr...
# 3        low             Weights important words more strongly.
# 4        low         Weights important words and short phrases.
# 5     medium        Handles slang, typos, and repeated letters.
# 6     medium  Character n-grams within word boundaries for n...
# 7     medium  Memory-efficient word hashing without storing ...
# 8     medium          Memory-efficient character-level hashing.
# 9       high  Compresses TF-IDF into lower-dimensional featu...
# Available classifiers:
#                     id                           name         family  \
# 0       multinomial_nb        Multinomial Naive Bayes    naive_bayes
# 1        complement_nb         Complement Naive Bayes    naive_bayes
# 2         bernoulli_nb          Bernoulli Naive Bayes    naive_bayes
# 3      logreg_balanced   Logistic Regression Balanced         linear
# 4     ridge_classifier               Ridge Classifier         linear
# 5           linear_svc                      LinearSVC   margin_based
# 6              sgd_log    SGDClassifier Logistic Loss            sgd
# 7            sgd_hinge       SGDClassifier Hinge Loss            sgd
# 8   passive_aggressive  Passive Aggressive Classifier  online_margin
# 9  random_forest_small            Small Random Forest     tree_based
#
#   complexity                                              notes
# 0        low  Very fast probabilistic baseline for text counts.
# 1        low  Naive Bayes variant useful for imbalanced text...
# 2        low               Uses feature presence/absence logic.
# 3        low              Simple explainable linear classifier.
# 4        low                     Regularized linear classifier.
# 5     medium    Strong margin-based classifier for sparse text.
# 6     medium                      Scalable logistic classifier.
# 7     medium                      Scalable SVM-like classifier.
# 8     medium               Fast online margin-based classifier.
# 9       high     One nonlinear tree-based model for comparison.
# Selected vectorizers: ['count_binary', 'count_bigram', 'tfidf_word', 'hashing_word']
# Selected classifiers: ['complement_nb', 'logreg_balanced', 'ridge_classifier', 'linear_svc']
# Vectorizer count: 4
# Classifier count: 4
# Vectorizer families: ['count_binary', 'count_ngram', 'hashing', 'tfidf']
# Classifier families: ['linear', 'margin_based', 'naive_bayes']
# Heavy classifiers: []
#
# Final diversity check passed.

# %%
# ============================================================
# STEP 14: Generate JSON submission manifest
# ============================================================

def json_safe(obj):
    # Convert tuples and numpy values to JSON-safe types.
    if isinstance(obj, tuple):
        return list(obj)
    if isinstance(obj, dict):
        return {k: json_safe(v) for k, v in obj.items()}
    if isinstance(obj, list):
        return [json_safe(x) for x in obj]
    if isinstance(obj, (np.integer,)):
        return int(obj)
    if isinstance(obj, (np.floating,)):
        return float(obj)
    return obj

STUDENT_NAME = "AAHAN LULLA"
TEAM_NAME = "N/A"

# Explain your research thinking in 3-5 lines.
STUDENT_HYPOTHESIS = (
    "I compared diverse vectorization approaches including binary count, TF-IDF, "
    "hashing, and n-gram representations to study frequency-based, importance-based, "
    "and scalable text representations. I compared probabilistic, linear, and "
    "margin-based classifiers while prioritizing accuracy, simplicity, efficiency, "
    "generalization, and model diversity. Final selections were based on performance across both datasets while avoiding over-complex models and near-duplicate choices."
)

best_80_pipeline = results_80.iloc[0].to_dict()

if "results_300" in globals() and isinstance(results_300, pd.DataFrame) and not results_300.empty:
    best_300_pipeline = results_300.iloc[0].to_dict()
else:
    best_300_pipeline = None

submission_manifest = {
    "student_name": STUDENT_NAME,
    "team_name": TEAM_NAME,
    "task_type": "entity_aware_sentiment_classification",
    "dataset_used_for_initial_experiment": "/content/ipl_sentiment_analysis.csv",
    "target_labels": sorted(df_80["sentiment"].unique().tolist()),
    "model_input_format": "subject_keyword + ' [SEP] ' + statement",
    "hypothesis": STUDENT_HYPOTHESIS,
    "final_vectorizers": json_safe(final_vectorizers),
    "final_classifiers": json_safe(final_classifiers),
    "best_80R_pipeline": json_safe(best_80_pipeline),
    "best_300R_pipeline": json_safe(best_300_pipeline),
    "files_expected": [
        "completed_notebook.ipynb",
        "submission_manifest.json",
        "results_80R.csv",
        "results_300R.csv if 300R was used"
    ],
}

print(json.dumps(submission_manifest, indent=2))

with open("submission_manifest.json", "w", encoding="utf-8") as f:
    json.dump(submission_manifest, f, indent=2)

print("\nSaved: submission_manifest.json")
# Out:
# {
#   "student_name": "AAHAN LULLA",
#   "team_name": "N/A",
#   "task_type": "entity_aware_sentiment_classification",
#   "dataset_used_for_initial_experiment": "/content/ipl_sentiment_analysis.csv",
#   "target_labels": [
#     "negative",
#     "neutral",
#     "positive"
#   ],
#   "model_input_format": "subject_keyword + ' [SEP] ' + statement",
#   "hypothesis": "I compared diverse vectorization approaches including binary count, TF-IDF, hashing, and n-gram representations to study frequency-based, importance-based, and scalable text representations. I compared probabilistic, linear, and margin-based classifiers while prioritizing accuracy, simplicity, efficiency, generalization, and model diversity. Final selections were based on performance across both datasets while avoiding over-complex models and near-duplicate choices.",
#   "final_vectorizers": [
#     {
#       "id": "count_binary",
#       "name": "Binary CountVectorizer",
#       "family": "count_binary",
#       "type": "CountVectorizer",
#       "params": {
#         "lowercase": true,
#         "binary": true,
#         "max_features": 3000
#       },
#       "notes": "Tests word presence instead of frequency.",
#       "complexity": "low"
#     },
#     {
#       "id": "count_bigram",
#       "name": "CountVectorizer 1-2 grams",
#       "family": "count_ngram",
#       "type": "CountVectorizer",
#       "params": {
#         "lowercase": true,
#         "ngram_range": [
#           1,
#           2
#         ],
#         "max_features": 4000
#       },
#       "notes": "Captures simple word frequencies and short phrases.",
#       "complexity": "low"
#     },
#     {
#       "id": "tfidf_word",
#       "name": "TF-IDF Word",
#       "family": "tfidf",
#       "type": "TfidfVectorizer",
#       "params": {
#         "lowercase": true,
#         "max_features": 4000
#       },
#       "notes": "Weights important words more strongly.",
#       "complexity": "low"
#     },
#     {
#       "id": "hashing_word",
#       "name": "HashingVectorizer Word",
#       "family": "hashing",
#       "type": "HashingVectorizer",
#       "params": {
#         "alternate_sign": false,
#         "n_features": 2048,
#         "lowercase": true
#       },
#       "notes": "Memory-efficient word hashing without storing vocabulary.",
#       "complexity": "medium"
#     }
#   ],
#   "final_classifiers": [
#     {
#       "id": "complement_nb",
#       "name": "Complement Naive Bayes",
#       "family": "naive_bayes",
#       "type": "ComplementNB",
#       "params": {},
#       "notes": "Naive Bayes variant useful for imbalanced text data.",
#       "complexity": "low"
#     },
#     {
#       "id": "logreg_balanced",
#       "name": "Logistic Regression Balanced",
#       "family": "linear",
#       "type": "LogisticRegression",
#       "params": {
#         "max_iter": 1000,
#         "class_weight": "balanced",
#         "random_state": 42
#       },
#       "notes": "Simple explainable linear classifier.",
#       "complexity": "low"
#     },
#     {
#       "id": "ridge_classifier",
#       "name": "Ridge Classifier",
#       "family": "linear",
#       "type": "RidgeClassifier",
#       "params": {},
#       "notes": "Regularized linear classifier.",
#       "complexity": "low"
#     },
#     {
#       "id": "linear_svc",
#       "name": "LinearSVC",
#       "family": "margin_based",
#       "type": "LinearSVC",
#       "params": {
#         "random_state": 42
#       },
#       "notes": "Strong margin-based classifier for sparse text.",
#       "complexity": "medium"
#     }
#   ],
#   "best_80R_pipeline": {
#     "rank": 1,
#     "vectorizer_id": "count_binary",
#     "vectorizer_name": "Binary CountVectorizer",
#     "vectorizer_family": "count_binary",
#     "vectorizer_complexity": "low",
#     "classifier_id": "ridge_classifier",
#     "classifier_name": "Ridge Classifier",
#     "classifier_family": "linear",
#     "classifier_complexity": "low",
#     "pipeline_id": "count_binary__ridge_classifier",
#     "status": "completed",
#     "accuracy": 0.75,
#     "macro_f1": 0.750445632798574,
#     "weighted_f1": 0.7379679144385027,
#     "precision_macro": 0.7833333333333333,
#     "recall_macro": 0.7619047619047619,
#     "train_time_sec": 0.011021614074707031,
#     "prediction_time_sec": 0.0012233257293701172,
#     "model_size_kb": 16.5673828125,
#     "performance_score": 74.84625668449198,
#     "efficiency_score": 99.52912311553956,
#     "suitability_score": 100,
#     "final_score": 86.0712657995785,
#     "error": ""
#   },
#   "best_300R_pipeline": {
#     "rank_300R": 1,
#     "vectorizer_id": "count_binary",
#     "vectorizer_name": "Binary CountVectorizer",
#     "vectorizer_family": "count_binary",
#     "vectorizer_complexity": "low",
#     "classifier_id": "logreg_balanced",
#     "classifier_name": "Logistic Regression Balanced",
#     "classifier_family": "linear",
#     "classifier_complexity": "low",
#     "pipeline_id": "count_binary__logreg_balanced",
#     "status": "completed",
#     "accuracy": 0.7473684210526316,
#     "macro_f1": 0.5095454908539021,
#     "weighted_f1": 0.7275820752456267,
#     "precision_macro": 0.49503161698283654,
#     "recall_macro": 0.5254122046574877,
#     "train_time_sec": 0.051444053649902344,
#     "prediction_time_sec": 0.00539398193359375,
#     "model_size_kb": 116.65625,
#     "performance_score": 60.17067110623431,
#     "efficiency_score": 97.03457176208497,
#     "suitability_score": 100,
#     "final_score": 77.50078346084587,
#     "error": ""
#   },
#   "files_expected": [
#     "completed_notebook.ipynb",
#     "submission_manifest.json",
#     "results_80R.csv",
#     "results_300R.csv if 300R was used"
#   ]
# }
#
# Saved: submission_manifest.json

# %% [markdown]
# # STEP 15: Final checklist before submission
#
# Submit these files:
#
# 1. Your completed notebook: `.ipynb`
# 2. `submission_manifest.json`
# 3. `results_80R.csv`
# 4. `results_300R.csv` if you used the 300-row dataset
#
# Your final JSON must contain exactly:
#
# - 4 vectorizers
# - 4 classifiers
#
# Before submitting, check:
#
# - Did you write your name and team name?
# - Did your notebook run from top to bottom?
# - Did you avoid near-duplicate choices?
# - Did you include at least 3 vectorizer families?
# - Did you include at least 3 classifier families?
# - Did you explain why you chose the final 4+4?
# - Did you avoid using many heavy models?
# - Did your model input include the subject keyword?
#
# Remember: a simple, explainable, fast model with decent performance can score better than a heavy model with only slightly higher accuracy.

# %%
# ============================================================
# OPTIONAL: Save your best 80R pipeline as a demo pkl
# ============================================================

SAVE_DEMO_BEST_PIPELINE = False

if SAVE_DEMO_BEST_PIPELINE:
    best_row = results_80.iloc[0]
    v_recipe = next(v for v in vectorizer_recipes if v["id"] == best_row["vectorizer_id"])
    c_recipe = next(c for c in classifier_recipes if c["id"] == best_row["classifier_id"])

    best_pipeline = make_pipeline(v_recipe, c_recipe)
    best_pipeline.fit(X, y)  # Train on all 80 rows only for demo use.

    joblib.dump(best_pipeline, "demo_best_80R_pipeline.pkl")
    print("Saved: demo_best_80R_pipeline.pkl")

    sample_text = "RCB [SEP] rcb batting mast thi but bowling thoda weak lag rhi hai"
    print("Sample prediction:", best_pipeline.predict([sample_text])[0])
else:
    print("Demo pickle saving is off. Set SAVE_DEMO_BEST_PIPELINE = True if needed.")
# Out:
# Demo pickle saving is off. Set SAVE_DEMO_BEST_PIPELINE = True if needed.
